# %% [markdown]
# # Notebook Pengingat Eksperimen
# Notebook ini dirancang untuk dijalankan di [Google Colab](https://colab.research.google.com/). Gunakan notebook ini untuk memasang Google Drive dan membaca konfigurasi `config.json` yang ada di folder proyek.

# %% [markdown]
# ## Cara menjalankan notebook
# 1. Buka notebook ini di Google Colab (klik `Open in Colab` atau unggah ke Colab).
# 2. Jalankan setiap sel dari atas ke bawah.
# 3. Saat menjalankan sel pemasangan Google Drive, berikan izin akses ketika Colab menampilkan tautan otorisasi.
# 4. Pastikan struktur folder di Google Drive adalah `MyDrive/project/` dengan subfolder `datasets/` dan `notebooks/`, serta file `config.json` berada langsung di dalam folder `project`.

# %% [markdown]
# ## 1. Pasang Google Drive ke Colab
# Sel berikut memasang Google Drive agar file proyek dapat diakses dari runtime Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Baca konfigurasi pengingat
# Selanjutnya, muat file `config.json` yang berisi placeholder webhook dan pesan pengingat. Jika file tidak ditemukan, periksa kembali lokasi folder proyek di Google Drive.

# %%
import json
from pathlib import Path

project_root = Path('/content/drive/MyDrive/project')
config_path = project_root / 'config.json'
with config_path.open() as fh:
    config = json.load(fh)
config
